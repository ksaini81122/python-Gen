# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
##reading the dataset
df = pd.read_csv("Used_Bikes.csv")
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.isnull().sum()
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(25324)

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
cat_col = df.select_dtypes(include="object")
cat_col
# Out:
#                                  bike_name       city        owner  \
# 0       TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner
# 1              Royal Enfield Classic 350cc      Delhi  First Owner
# 2                     Triumph Daytona 675R      Delhi  First Owner
# 3                     TVS Apache RTR 180cc  Bangalore  First Owner
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner
# ...                                    ...        ...          ...
# 9362             Hero Hunk Rear Disc 150cc      Delhi  First Owner
# 9369                   Bajaj Avenger 220cc  Bangalore  First Owner
# 9370        Harley-Davidson Street 750 ABS    Jodhpur  First Owner
# 9371                 Bajaj Dominar 400 ABS  Hyderabad  First Owner
# 9372              Bajaj Avenger Street 220  Hyderabad  First Owner
#
#                 brand
# 0                 TVS
# 1       Royal Enfield
# 2             Triumph
# 3                 TVS
# 4              Yamaha
# ...

# %%
num_col = df.select_dtypes(exclude = "object")
num_col
# Out:
#          price  kms_driven  age  power
# 0      35000.0     17654.0  3.0  110.0
# 1     119900.0     11000.0  4.0  350.0
# 2     600000.0       110.0  8.0  675.0
# 3      65000.0     16329.0  4.0  180.0
# 4      80000.0     10000.0  3.0  150.0
# ...        ...         ...  ...    ...
# 9362   25000.0     48587.0  8.0  150.0
# 9369   35000.0     60000.0  9.0  220.0
# 9370  450000.0      3430.0  4.0  750.0
# 9371  139000.0     21300.0  4.0  400.0
# 9372   80000.0      7127.0  5.0  220.0
#
# [7324 rows x 4 columns]

# %%
cat_col = cat_col.drop(["bike_name" , "city"],axis=1)
cat_col
# Out:
#             owner            brand
# 0     First Owner              TVS
# 1     First Owner    Royal Enfield
# 2     First Owner          Triumph
# 3     First Owner              TVS
# 4     First Owner           Yamaha
# ...           ...              ...
# 9362  First Owner             Hero
# 9369  First Owner            Bajaj
# 9370  First Owner  Harley-Davidson
# 9371  First Owner            Bajaj
# 9372  First Owner            Bajaj
#
# [7324 rows x 2 columns]

# %%
df["owner"].value_counts()
# Out:
# owner
# First Owner             6642
# Second Owner             588
# Third Owner               84
# Fourth Owner Or More      10
# Name: count, dtype: int64

# %%
cat_col["owner"] = cat_col["owner"].map({"First Owner":1,"Second Owner":2,"Third Owner":3,"Fourth Owner Or More":4})

# %%
cat_col
# Out:
#       owner            brand
# 0         1              TVS
# 1         1    Royal Enfield
# 2         1          Triumph
# 3         1              TVS
# 4         1           Yamaha
# ...     ...              ...
# 9362      1             Hero
# 9369      1            Bajaj
# 9370      1  Harley-Davidson
# 9371      1            Bajaj
# 9372      1            Bajaj
#
# [7324 rows x 2 columns]

# %%
{i:key for key , i in enumerate(list(cat_col['brand'].unique()))}  ## i is index for enumerate and key is the brand name for (cat_col['brand'].unique())
# Out:
# {'TVS': 0,
#  'Royal Enfield': 1,
#  'Triumph': 2,
#  'Yamaha': 3,
#  'Honda': 4,
#  'Hero': 5,
#  'Bajaj': 6,
#  'Suzuki': 7,
#  'Benelli': 8,
#  'KTM': 9,
#  'Mahindra': 10,
#  'Kawasaki': 11,
#  'Ducati': 12,
#  'Hyosung': 13,
#  'Harley-Davidson': 14,
#  'Jawa': 15,
#  'BMW': 16,
#  'Indian': 17,
#  'Rajdoot': 18,
#  'LML': 19,
#  'Yezdi': 20,
#  'MV': 21,
#  'Ideal': 22}

# %%
dt = {'TVS': 0,
 'Royal Enfield': 1,
 'Triumph': 2,
 'Yamaha': 3,
 'Honda': 4,
 'Hero': 5,
 'Bajaj': 6,
 'Suzuki': 7,
 'Benelli': 8,
 'KTM': 9,
 'Mahindra': 10,
 'Kawasaki': 11,
 'Ducati': 12,
 'Hyosung': 13,
 'Harley-Davidson': 14,
 'Jawa': 15,
 'BMW': 16,
 'Indian': 17,
 'Rajdoot': 18,
 'LML': 19,
 'Yezdi': 20,
 'MV': 21,
 'Ideal': 22}

# %%
cat_col["brand"] = cat_col["brand"].map(dt)

# %%
cat_col
# Out:
#       owner  brand
# 0         1      0
# 1         1      1
# 2         1      2
# 3         1      0
# 4         1      3
# ...     ...    ...
# 9362      1      5
# 9369      1      6
# 9370      1     14
# 9371      1      6
# 9372      1      6
#
# [7324 rows x 2 columns]

# %%
final_df = pd.concat([cat_col,num_col],axis=1)
final_df
# Out:
#       owner  brand     price  kms_driven  age  power
# 0         1      0   35000.0     17654.0  3.0  110.0
# 1         1      1  119900.0     11000.0  4.0  350.0
# 2         1      2  600000.0       110.0  8.0  675.0
# 3         1      0   65000.0     16329.0  4.0  180.0
# 4         1      3   80000.0     10000.0  3.0  150.0
# ...     ...    ...       ...         ...  ...    ...
# 9362      1      5   25000.0     48587.0  8.0  150.0
# 9369      1      6   35000.0     60000.0  9.0  220.0
# 9370      1     14  450000.0      3430.0  4.0  750.0
# 9371      1      6  139000.0     21300.0  4.0  400.0
# 9372      1      6   80000.0      7127.0  5.0  220.0
#
# [7324 rows x 6 columns]

# %%
##data divide x and y -- 
x = final_df.drop("price",axis=1)
y = final_df[["price"]]

# %%
##data ko divide training and testing --80-20 ratio
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,
                                                 random_state=42)

# %%
# Feature scaling
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
#  Define ANN Model (Same Architecture as Sample)
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Define the model first
model = Sequential()

# Now you can add layers
model.add(Dense(68, activation="relu", input_dim=x_train_scaled.shape[1]))
model.add(Dense(32, activation="relu"))
model.add(Dense(24, activation="relu"))
model.add(Dense(12, activation="relu"))
model.add(Dense(1, activation="sigmoid"))
# Out:
# c:\Users\ksain\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the Model
model.compile(loss="mean_squared_error", optimizer="adam", metrics=["mae"])

# %%
#  Train the Model
model.fit(x_train_scaled, y_train, epochs=20, validation_data=(x_test_scaled, y_test))
# Out:
# Epoch 1/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 18679986176.0000 - mae: 81898.6250 - val_loss: 27384690688.0000 - val_mae: 88971.7422
# Epoch 2/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 21173266432.0000 - mae: 83319.2812 - val_loss: 27384690688.0000 - val_mae: 88971.7422
# Epoch 3/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 19136956416.0000 - mae: 82594.4922 - val_loss: 27384690688.0000 - val_mae: 88971.7422
# Epoch 4/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 21382572032.0000 - mae: 84869.3281 - val_loss: 27384690688.0000 - val_mae: 88971.7422
# Epoch 5/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 24516876288.0000 - mae: 86148.3594 - val_loss: 27384690688.0000 - val_mae: 88971.7422
# Epoch 6/20
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 20718139392.0000 - mae: 82900.0781 - val_loss: 27384690688.0000 - val_mae: 88971.7422
# Epoch 7/20
# ...

# %%
#  Model Summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 68)             │           408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 24)             │           792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 12)             │           300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            13 │
# ...
